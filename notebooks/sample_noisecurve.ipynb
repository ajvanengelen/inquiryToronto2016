# %%
import sys
sys.path.append("../py")
import transitTools
# %pylab inline
# Out:
# /Users/engelen/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib

# %%
totalObservingTimeInMinutes = 30*60
samplingRatePerMinute = 1
time = arange(0, totalObservingTimeInMinutes, samplingRatePerMinute)

# %%
noise =  transitTools.noise(totalObservingTimeInMinutes = totalObservingTimeInMinutes,
                                samplingRatePerMinute = samplingRatePerMinute,
                                amplitude = 0.01, 
                                kneeFreq = 1000, doPlots = False, powerLawIndex = 0)

# %%
plot(time, noise)
xlabel("time in minutes")
print(mean(noise))
# Out:
# -0.000377505543527

# %%
signal = transitTools.transit(time,
    rho=0.459,          # density of main star (solar density)
    ld1=0.2,            # limb darkening coefficients (2 coeff's for quadratic limb darkening)
    ld2=0.4,
    period =1., # in days
    impact=0.,  # between 0 and 1 yields a transit
    rprs=0.4,    # radii ratio
    T0 = float(totalObservingTimeInMinutes ) / 2. / (24. * 60))

#fig = plt.figure(figsize=(9,7))
#plt.plot(center(phased(time)),flux,'.',MarkerSize=2)
plot(time, signal + noise, 'b.')
plot(time,signal,'r')

xlabel('time (minutes)',fontsize='18')
ylabel('Relative Flux',fontsize='18')
xlim(min(time),max(time))

#plt.savefig('_plots/LBM_LC_overplot.ps')
# Out:
# (0, 1799)

# %%
time
